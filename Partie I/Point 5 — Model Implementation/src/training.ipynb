# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/crop-classification/Partie\ I/Point\ 5\ —\ Model\ Implementation/
# Out:
# /content/drive/MyDrive/crop-classification/Partie I/Point 5 — Model Implementation

# %%
# !python train.py --region Arkansas --data_dir ../../data/preprocessed/scale30
# Out:
# ============================================================
# MCTNet — Arkansas  (5 classes)  [scale30]
# Device : cpu
# Hyperparametres : {'lr': 0.001, 'batch_size': 32, 'epochs': 200, 'n_head': 5, 'kernel_size': 3, 'dropout': 0.1, 'print_every': 10}
# Data dir : ../../data/preprocessed/scale30
# ============================================================
#
# Donnees : 1200 train | 300 val | 8500 test
# Parametres : 56,798  (article Table 6 : 55 059)
#
# Epoch   1/200 | train_loss=1.0677 | val_loss=1.2198 | val_OA=0.3367 | val_Kappa=0.1708 | val_F1=0.2658 | best_F1=0.2658 (ep1) | 3s
# Epoch  10/200 | train_loss=0.0463 | val_loss=0.2144 | val_OA=0.9267 | val_Kappa=0.9083 | val_F1=0.9264 | best_F1=0.9567 (ep6) | 18s
# Epoch  20/200 | train_loss=0.0174 | val_loss=0.1292 | val_OA=0.9667 | val_Kappa=0.9583 | val_F1=0.9666 | best_F1=0.9732 (ep19) | 35s
# Epoch  30/200 | train_loss=0.0050 | val_loss=0.1159 | val_OA=0.9700 | val_Kappa=0.9625 | val_F1=0.9699 | best_F1=0.9766 (ep23) | 52s
# Epoch  40/200 | train_loss=0.0782 | val_loss=0.1933 | val_OA=0.9333 | val_Kappa=0.9167 | val_F1=0.9318 | best_F1=0.9766 (ep32) | 68s
# Epoch  50/200 | train_loss=0.0028 | val_loss=0.1380 | val_OA=0.9700 | val_Kappa=0.9625 | val_F1=0.9699 | best_F1=0.9766 (ep32) | 84s
# Epoch  60/200 | train_loss=0.0102 | val_loss=0.1379 | val_OA=0.9667 | val_Kappa=0.9583 | val_F1=0.9669 | best_F1=0.9766 (ep32) | 101s
# Epoch  70/200 | train_loss=0.0004 | val_loss=0.1399 | val_OA=0.9700 | val_Kappa=0.9625 | val_F1=0.9698 | best_F1=0.9766 (ep32) | 117s
# Epoch  80/200 | train_loss=0.0044 | val_loss=0.1747 | val_OA=0.9533 | val_Kappa=0.9417 | val_F1=0.9528 | best_F1=0.9766 (ep32) | 134s
# Epoch  90/200 | train_loss=0.0005 | val_loss=0.1182 | val_OA=0.9700 | val_Kappa=0.9625 | val_F1=0.9698 | best_F1=0.9766 (ep32) | 151s
# Epoch 100/200 | train_loss=0.0003 | val_loss=0.1244 | val_OA=0.9700 | val_Kappa=0.9625 | val_F1=0.9698 | best_F1=0.9767 (ep97) | 167s
# Epoch 110/200 | train_loss=0.0002 | val_loss=0.1290 | val_OA=0.9733 | val_Kappa=0.9667 | val_F1=0.9732 | best_F1=0.9767 (ep97) | 183s
# Epoch 120/200 | train_loss=0.0001 | val_loss=0.1352 | val_OA=0.9733 | val_Kappa=0.9667 | val_F1=0.9733 | best_F1=0.9767 (ep97) | 199s
# Epoch 130/200 | train_loss=0.0001 | val_loss=0.1389 | val_OA=0.9733 | val_Kappa=0.9667 | val_F1=0.9733 | best_F1=0.9767 (ep97) | 216s
# Epoch 140/200 | train_loss=0.0001 | val_loss=0.1339 | val_OA=0.9733 | val_Kappa=0.9667 | val_F1=0.9733 | best_F1=0.9767 (ep97) | 232s
# Epoch 150/200 | train_loss=0.0001 | val_loss=0.1388 | val_OA=0.9733 | val_Kappa=0.9667 | val_F1=0.9733 | best_F1=0.9767 (ep97) | 248s
# Epoch 160/200 | train_loss=0.0001 | val_loss=0.1516 | val_OA=0.9733 | val_Kappa=0.9667 | val_F1=0.9733 | best_F1=0.9767 (ep97) | 265s
# Epoch 170/200 | train_loss=0.1462 | val_loss=0.1625 | val_OA=0.9567 | val_Kappa=0.9458 | val_F1=0.9567 | best_F1=0.9767 (ep97) | 282s
# Epoch 180/200 | train_loss=0.0019 | val_loss=0.1338 | val_OA=0.9633 | val_Kappa=0.9542 | val_F1=0.9633 | best_F1=0.9767 (ep97) | 298s
# Epoch 190/200 | train_loss=0.0166 | val_loss=0.1300 | val_OA=0.9600 | val_Kappa=0.9500 | val_F1=0.9601 | best_F1=0.9767 (ep97) | 314s
# Epoch 200/200 | train_loss=0.0048 | val_loss=0.1208 | val_OA=0.9767 | val_Kappa=0.9708 | val_F1=0.9767 | best_F1=0.9767 (ep97) | 330s
#
# Chargement du meilleur modele (epoch 97, val_F1=0.9767)...
#
# ============================================================
# RESULTATS FINAUX — Arkansas
# ============================================================
#   OA    : 0.9787  (article : 0.968)
#   Kappa : 0.9734  (article : 0.951)
#   F1    : 0.9787  (article : 0.933)
#
# Modele sauvegarde : best_Arkansas_scale30.pth

# %%
# !python train.py --region California --data_dir ../../data/preprocessed/scale30
# Out:
# ============================================================
# MCTNet — California  (6 classes)  [scale30]
# Device : cpu
# Hyperparametres : {'lr': 0.001, 'batch_size': 32, 'epochs': 200, 'n_head': 5, 'kernel_size': 3, 'dropout': 0.1, 'print_every': 10}
# Data dir : ../../data/preprocessed/scale30
# ============================================================
#
# Donnees : 1440 train | 360 val | 8200 test
# Parametres : 56,879  (article Table 6 : 55 059)
#
# Epoch   1/200 | train_loss=0.8885 | val_loss=0.8444 | val_OA=0.6222 | val_Kappa=0.5467 | val_F1=0.5844 | best_F1=0.5844 (ep1) | 2s
# Epoch  10/200 | train_loss=0.1477 | val_loss=0.2334 | val_OA=0.9167 | val_Kappa=0.9000 | val_F1=0.9157 | best_F1=0.9499 (ep9) | 21s
# Epoch  20/200 | train_loss=0.0781 | val_loss=0.1608 | val_OA=0.9667 | val_Kappa=0.9600 | val_F1=0.9665 | best_F1=0.9693 (ep19) | 40s
# Epoch  30/200 | train_loss=0.0475 | val_loss=0.1737 | val_OA=0.9611 | val_Kappa=0.9533 | val_F1=0.9603 | best_F1=0.9694 (ep25) | 59s
# Epoch  40/200 | train_loss=0.0321 | val_loss=0.1483 | val_OA=0.9583 | val_Kappa=0.9500 | val_F1=0.9586 | best_F1=0.9694 (ep25) | 80s
# Epoch  50/200 | train_loss=0.0095 | val_loss=0.1501 | val_OA=0.9611 | val_Kappa=0.9533 | val_F1=0.9612 | best_F1=0.9694 (ep25) | 99s
# Epoch  60/200 | train_loss=0.0131 | val_loss=0.2008 | val_OA=0.9528 | val_Kappa=0.9433 | val_F1=0.9525 | best_F1=0.9694 (ep25) | 118s
# Epoch  70/200 | train_loss=0.0096 | val_loss=0.1614 | val_OA=0.9639 | val_Kappa=0.9567 | val_F1=0.9637 | best_F1=0.9694 (ep25) | 139s
# Epoch  80/200 | train_loss=0.0016 | val_loss=0.1556 | val_OA=0.9667 | val_Kappa=0.9600 | val_F1=0.9667 | best_F1=0.9694 (ep25) | 158s
# Epoch  90/200 | train_loss=0.0093 | val_loss=0.1693 | val_OA=0.9611 | val_Kappa=0.9533 | val_F1=0.9612 | best_F1=0.9694 (ep25) | 177s
# Epoch 100/200 | train_loss=0.0033 | val_loss=0.1846 | val_OA=0.9500 | val_Kappa=0.9400 | val_F1=0.9501 | best_F1=0.9721 (ep93) | 198s
# Epoch 110/200 | train_loss=0.0115 | val_loss=0.2643 | val_OA=0.9556 | val_Kappa=0.9467 | val_F1=0.9553 | best_F1=0.9721 (ep93) | 217s
# Epoch 120/200 | train_loss=0.0005 | val_loss=0.1814 | val_OA=0.9639 | val_Kappa=0.9567 | val_F1=0.9640 | best_F1=0.9721 (ep93) | 237s
# Epoch 130/200 | train_loss=0.0005 | val_loss=0.1844 | val_OA=0.9694 | val_Kappa=0.9633 | val_F1=0.9695 | best_F1=0.9722 (ep127) | 257s
# Epoch 140/200 | train_loss=0.0002 | val_loss=0.1917 | val_OA=0.9667 | val_Kappa=0.9600 | val_F1=0.9667 | best_F1=0.9722 (ep127) | 276s
# Epoch 150/200 | train_loss=0.0001 | val_loss=0.2029 | val_OA=0.9694 | val_Kappa=0.9633 | val_F1=0.9695 | best_F1=0.9722 (ep127) | 296s
# Epoch 160/200 | train_loss=0.0323 | val_loss=0.2813 | val_OA=0.9389 | val_Kappa=0.9267 | val_F1=0.9382 | best_F1=0.9722 (ep127) | 316s
# Epoch 170/200 | train_loss=0.0009 | val_loss=0.1869 | val_OA=0.9611 | val_Kappa=0.9533 | val_F1=0.9614 | best_F1=0.9722 (ep127) | 335s
# Epoch 180/200 | train_loss=0.0078 | val_loss=0.2130 | val_OA=0.9611 | val_Kappa=0.9533 | val_F1=0.9610 | best_F1=0.9778 (ep177) | 356s
# Epoch 190/200 | train_loss=0.0036 | val_loss=0.1944 | val_OA=0.9528 | val_Kappa=0.9433 | val_F1=0.9529 | best_F1=0.9778 (ep177) | 375s
# Epoch 200/200 | train_loss=0.0003 | val_loss=0.2077 | val_OA=0.9583 | val_Kappa=0.9500 | val_F1=0.9583 | best_F1=0.9778 (ep177) | 394s
#
# Chargement du meilleur modele (epoch 177, val_F1=0.9778)...
#
# ============================================================
# RESULTATS FINAUX — California
# ============================================================
#   OA    : 0.9534  (article : 0.852)
#   Kappa : 0.9383  (article : 0.806)
#   F1    : 0.9317  (article : 0.829)
#
# Modele sauvegarde : best_California_scale30.pth

# %%
# !python train.py --region Arkansas --data_dir ../../data/preprocessed/scale20
# Out:
# ============================================================
# MCTNet — Arkansas  (5 classes)  [scale20]
# Device : cpu
# Hyperparametres : {'lr': 0.001, 'batch_size': 32, 'epochs': 200, 'n_head': 5, 'kernel_size': 3, 'dropout': 0.1, 'print_every': 10}
# Data dir : ../../data/preprocessed/scale20
# ============================================================
#
# Donnees : 1200 train | 300 val | 8500 test
# Parametres : 56,798  (article Table 6 : 55 059)
#
# Epoch   1/200 | train_loss=1.0155 | val_loss=1.0889 | val_OA=0.5533 | val_Kappa=0.4417 | val_F1=0.5288 | best_F1=0.5288 (ep1) | 2s
# Epoch  10/200 | train_loss=0.0734 | val_loss=0.1182 | val_OA=0.9533 | val_Kappa=0.9417 | val_F1=0.9533 | best_F1=0.9633 (ep8) | 17s
# Epoch  20/200 | train_loss=0.0159 | val_loss=0.1166 | val_OA=0.9633 | val_Kappa=0.9542 | val_F1=0.9633 | best_F1=0.9731 (ep18) | 35s
# Epoch  30/200 | train_loss=0.0157 | val_loss=0.1251 | val_OA=0.9633 | val_Kappa=0.9542 | val_F1=0.9632 | best_F1=0.9731 (ep18) | 53s
# Epoch  40/200 | train_loss=0.0405 | val_loss=0.2771 | val_OA=0.9167 | val_Kappa=0.8958 | val_F1=0.9151 | best_F1=0.9766 (ep36) | 69s
# Epoch  50/200 | train_loss=0.0130 | val_loss=0.1173 | val_OA=0.9600 | val_Kappa=0.9500 | val_F1=0.9601 | best_F1=0.9832 (ep49) | 86s
# Epoch  60/200 | train_loss=0.0007 | val_loss=0.1066 | val_OA=0.9767 | val_Kappa=0.9708 | val_F1=0.9765 | best_F1=0.9832 (ep49) | 103s
# Epoch  70/200 | train_loss=0.0004 | val_loss=0.1026 | val_OA=0.9733 | val_Kappa=0.9667 | val_F1=0.9731 | best_F1=0.9832 (ep49) | 121s
# Epoch  80/200 | train_loss=0.0003 | val_loss=0.1153 | val_OA=0.9767 | val_Kappa=0.9708 | val_F1=0.9764 | best_F1=0.9832 (ep49) | 139s
# Epoch  90/200 | train_loss=0.0003 | val_loss=0.1103 | val_OA=0.9767 | val_Kappa=0.9708 | val_F1=0.9765 | best_F1=0.9832 (ep49) | 156s
# Epoch 100/200 | train_loss=0.0002 | val_loss=0.1156 | val_OA=0.9767 | val_Kappa=0.9708 | val_F1=0.9765 | best_F1=0.9832 (ep49) | 172s
# Epoch 110/200 | train_loss=0.0002 | val_loss=0.1203 | val_OA=0.9767 | val_Kappa=0.9708 | val_F1=0.9764 | best_F1=0.9832 (ep49) | 189s
# Epoch 120/200 | train_loss=0.0028 | val_loss=0.0885 | val_OA=0.9767 | val_Kappa=0.9708 | val_F1=0.9765 | best_F1=0.9832 (ep49) | 205s
# Epoch 130/200 | train_loss=0.0021 | val_loss=0.1278 | val_OA=0.9567 | val_Kappa=0.9458 | val_F1=0.9567 | best_F1=0.9832 (ep49) | 222s
# Epoch 140/200 | train_loss=0.0003 | val_loss=0.0898 | val_OA=0.9667 | val_Kappa=0.9583 | val_F1=0.9665 | best_F1=0.9832 (ep49) | 239s
# Epoch 150/200 | train_loss=0.0002 | val_loss=0.1072 | val_OA=0.9700 | val_Kappa=0.9625 | val_F1=0.9699 | best_F1=0.9832 (ep49) | 256s
# Epoch 160/200 | train_loss=0.0001 | val_loss=0.1015 | val_OA=0.9667 | val_Kappa=0.9583 | val_F1=0.9665 | best_F1=0.9832 (ep49) | 272s
# Epoch 170/200 | train_loss=0.0001 | val_loss=0.1029 | val_OA=0.9733 | val_Kappa=0.9667 | val_F1=0.9733 | best_F1=0.9832 (ep49) | 289s
# Epoch 180/200 | train_loss=0.0001 | val_loss=0.0993 | val_OA=0.9767 | val_Kappa=0.9708 | val_F1=0.9766 | best_F1=0.9832 (ep49) | 305s
# Epoch 190/200 | train_loss=0.0002 | val_loss=0.1052 | val_OA=0.9733 | val_Kappa=0.9667 | val_F1=0.9730 | best_F1=0.9866 (ep186) | 322s
# Epoch 200/200 | train_loss=0.0015 | val_loss=0.0932 | val_OA=0.9700 | val_Kappa=0.9625 | val_F1=0.9701 | best_F1=0.9866 (ep186) | 338s
#
# Chargement du meilleur modele (epoch 186, val_F1=0.9866)...
#
# ============================================================
# RESULTATS FINAUX — Arkansas
# ============================================================
#   OA    : 0.9836  (article : 0.968)
#   Kappa : 0.9796  (article : 0.951)
#   F1    : 0.9836  (article : 0.933)
#
# Modele sauvegarde : best_Arkansas_scale20.pth

# %%
# !python train.py --region California --data_dir ../../data/preprocessed/scale20
# Out:
# ============================================================
# MCTNet — California  (6 classes)  [scale20]
# Device : cpu
# Hyperparametres : {'lr': 0.001, 'batch_size': 32, 'epochs': 200, 'n_head': 5, 'kernel_size': 3, 'dropout': 0.1, 'print_every': 10}
# Data dir : ../../data/preprocessed/scale20
# ============================================================
#
# Donnees : 1440 train | 360 val | 8200 test
# Parametres : 56,879  (article Table 6 : 55 059)
#
# Epoch   1/200 | train_loss=1.0000 | val_loss=0.9259 | val_OA=0.6639 | val_Kappa=0.5967 | val_F1=0.6205 | best_F1=0.6205 (ep1) | 2s
# Epoch  10/200 | train_loss=0.1639 | val_loss=0.2545 | val_OA=0.9139 | val_Kappa=0.8967 | val_F1=0.9158 | best_F1=0.9314 (ep9) | 20s
# Epoch  20/200 | train_loss=0.1093 | val_loss=0.3418 | val_OA=0.8972 | val_Kappa=0.8767 | val_F1=0.8977 | best_F1=0.9481 (ep17) | 40s
# Epoch  30/200 | train_loss=0.0487 | val_loss=0.2401 | val_OA=0.9444 | val_Kappa=0.9333 | val_F1=0.9455 | best_F1=0.9481 (ep17) | 59s
# Epoch  40/200 | train_loss=0.0293 | val_loss=0.2606 | val_OA=0.9389 | val_Kappa=0.9267 | val_F1=0.9398 | best_F1=0.9481 (ep17) | 80s
# Epoch  50/200 | train_loss=0.0234 | val_loss=0.2939 | val_OA=0.9278 | val_Kappa=0.9133 | val_F1=0.9287 | best_F1=0.9481 (ep17) | 99s
# Epoch  60/200 | train_loss=0.0175 | val_loss=0.2845 | val_OA=0.9389 | val_Kappa=0.9267 | val_F1=0.9394 | best_F1=0.9481 (ep17) | 119s
# Epoch  70/200 | train_loss=0.0058 | val_loss=0.3047 | val_OA=0.9417 | val_Kappa=0.9300 | val_F1=0.9424 | best_F1=0.9481 (ep17) | 139s
# Epoch  80/200 | train_loss=0.0128 | val_loss=0.3203 | val_OA=0.9361 | val_Kappa=0.9233 | val_F1=0.9371 | best_F1=0.9481 (ep17) | 158s
# Epoch  90/200 | train_loss=0.0052 | val_loss=0.2559 | val_OA=0.9389 | val_Kappa=0.9267 | val_F1=0.9393 | best_F1=0.9481 (ep17) | 177s
# Epoch 100/200 | train_loss=0.0006 | val_loss=0.2961 | val_OA=0.9444 | val_Kappa=0.9333 | val_F1=0.9452 | best_F1=0.9506 (ep96) | 198s
# Epoch 110/200 | train_loss=0.0019 | val_loss=0.3074 | val_OA=0.9389 | val_Kappa=0.9267 | val_F1=0.9395 | best_F1=0.9507 (ep101) | 217s
# Epoch 120/200 | train_loss=0.0062 | val_loss=0.2885 | val_OA=0.9333 | val_Kappa=0.9200 | val_F1=0.9340 | best_F1=0.9507 (ep101) | 236s
# Epoch 130/200 | train_loss=0.0018 | val_loss=0.3662 | val_OA=0.9333 | val_Kappa=0.9200 | val_F1=0.9347 | best_F1=0.9507 (ep101) | 257s
# Epoch 140/200 | train_loss=0.0004 | val_loss=0.3400 | val_OA=0.9361 | val_Kappa=0.9233 | val_F1=0.9371 | best_F1=0.9507 (ep101) | 276s
# Epoch 150/200 | train_loss=0.0003 | val_loss=0.3322 | val_OA=0.9333 | val_Kappa=0.9200 | val_F1=0.9339 | best_F1=0.9507 (ep101) | 296s
# Epoch 160/200 | train_loss=0.0001 | val_loss=0.3479 | val_OA=0.9417 | val_Kappa=0.9300 | val_F1=0.9426 | best_F1=0.9507 (ep101) | 316s
# Epoch 170/200 | train_loss=0.0001 | val_loss=0.3605 | val_OA=0.9417 | val_Kappa=0.9300 | val_F1=0.9426 | best_F1=0.9507 (ep101) | 335s
# Epoch 180/200 | train_loss=0.1707 | val_loss=0.2756 | val_OA=0.9361 | val_Kappa=0.9233 | val_F1=0.9373 | best_F1=0.9507 (ep101) | 356s
# Epoch 190/200 | train_loss=0.0019 | val_loss=0.3065 | val_OA=0.9361 | val_Kappa=0.9233 | val_F1=0.9368 | best_F1=0.9507 (ep101) | 375s
# Epoch 200/200 | train_loss=0.0098 | val_loss=0.3694 | val_OA=0.9250 | val_Kappa=0.9100 | val_F1=0.9269 | best_F1=0.9507 (ep101) | 394s
#
# Chargement du meilleur modele (epoch 101, val_F1=0.9507)...
#
# ============================================================
# RESULTATS FINAUX — California
# ============================================================
#   OA    : 0.9610  (article : 0.852)
#   Kappa : 0.9481  (article : 0.806)
#   F1    : 0.9420  (article : 0.829)
#
# Modele sauvegarde : best_California_scale20.pth

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/CROP-MAPPING-PART3/Point 5 — Model Implementation
# Out:
# /content/drive/MyDrive/CROP-MAPPING-PART3/Point 5 — Model Implementation

# %% [markdown]
# # **MULTI SCALING NO EARLY STOPPING**

# %%
# !python train_visu.py --region Arkansas --data_dir ../data_train
# Out:
# ...
# MCTNet — Arkansas
# Device : cpu
# ...
# Epoch   1/200 | train_loss=0.8226 | val_loss=0.7715 | OA=0.7233 | Kappa=0.6542 | F1=0.7304 | best_F1=0.7304 | 3s
# Epoch  10/200 | train_loss=0.0522 | val_loss=0.2435 | OA=0.9333 | Kappa=0.9167 | F1=0.9331 | best_F1=0.9331 | 31s
# Epoch  20/200 | train_loss=0.0255 | val_loss=0.1531 | OA=0.9633 | Kappa=0.9542 | F1=0.9630 | best_F1=0.9666 | 62s
# Epoch  30/200 | train_loss=0.0115 | val_loss=0.1785 | OA=0.9600 | Kappa=0.9500 | F1=0.9595 | best_F1=0.9697 | 92s
# Epoch  40/200 | train_loss=0.0173 | val_loss=0.1597 | OA=0.9667 | Kappa=0.9583 | F1=0.9664 | best_F1=0.9697 | 123s
# Epoch  50/200 | train_loss=0.0009 | val_loss=0.1715 | OA=0.9600 | Kappa=0.9500 | F1=0.9597 | best_F1=0.9698 | 153s
# Epoch  60/200 | train_loss=0.0003 | val_loss=0.1656 | OA=0.9667 | Kappa=0.9583 | F1=0.9665 | best_F1=0.9698 | 184s
# Epoch  70/200 | train_loss=0.0454 | val_loss=0.2565 | OA=0.9333 | Kappa=0.9167 | F1=0.9331 | best_F1=0.9698 | 215s
# ...

# %%
# !python train_visu.py --region California --data_dir ../data_train
# Out:
# ...
# MCTNet — California
# Device : cpu
# ...
# Epoch   1/200 | train_loss=0.9213 | val_loss=0.8106 | OA=0.7278 | Kappa=0.6733 | F1=0.7197 | best_F1=0.7197 | 4s
# Epoch  10/200 | train_loss=0.1255 | val_loss=0.3709 | OA=0.8722 | Kappa=0.8467 | F1=0.8762 | best_F1=0.9127 | 37s
# Epoch  20/200 | train_loss=0.0547 | val_loss=0.3671 | OA=0.9139 | Kappa=0.8967 | F1=0.9141 | best_F1=0.9288 | 74s
# Epoch  30/200 | train_loss=0.0349 | val_loss=0.3215 | OA=0.9333 | Kappa=0.9200 | F1=0.9333 | best_F1=0.9333 | 111s
# Epoch  40/200 | train_loss=0.0215 | val_loss=0.3471 | OA=0.9139 | Kappa=0.8967 | F1=0.9142 | best_F1=0.9333 | 147s
# Epoch  50/200 | train_loss=0.0440 | val_loss=0.4755 | OA=0.8833 | Kappa=0.8600 | F1=0.8860 | best_F1=0.9390 | 185s
# Epoch  60/200 | train_loss=0.0006 | val_loss=0.3765 | OA=0.9389 | Kappa=0.9267 | F1=0.9390 | best_F1=0.9390 | 221s
# Epoch  70/200 | train_loss=0.0003 | val_loss=0.3965 | OA=0.9361 | Kappa=0.9233 | F1=0.9361 | best_F1=0.9390 | 259s
# ...

# %% [markdown]
# # **AVEC EARLYSTOPPING**

# %%
# !python train_early.py --region Arkansas --data_dir ../data_train
# Out:
# ...
# MCTNet — Arkansas
# Device : cpu
# Data dir : ../data_train
# ...
#
# Donnees : 1200 train | 300 val | 8523 test
# Parametres : 156,198
# Epoch   1/200 | train_loss=0.8897 | val_loss=0.7189 | OA=0.7133 | Kappa=0.6417 | F1=0.6990 | best_F1=0.6990 | 3s
# Epoch  10/200 | train_loss=0.0535 | val_loss=0.1821 | OA=0.9467 | Kappa=0.9333 | F1=0.9464 | best_F1=0.9464 | 31s
# Epoch  20/200 | train_loss=0.0414 | val_loss=0.2215 | OA=0.9400 | Kappa=0.9250 | F1=0.9396 | best_F1=0.9563 | 62s
# Epoch  30/200 | train_loss=0.0016 | val_loss=0.1898 | OA=0.9600 | Kappa=0.9500 | F1=0.9595 | best_F1=0.9665 | 93s
# Epoch  40/200 | train_loss=0.0013 | val_loss=0.2080 | OA=0.9533 | Kappa=0.9417 | F1=0.9530 | best_F1=0.9665 | 124s
# Epoch  50/200 | train_loss=0.0004 | val_loss=0.2272 | OA=0.9567 | Kappa=0.9458 | F1=0.9562 | best_F1=0.9665 | 156s
#
# Early stopping à l'epoch 54 (best epoch=29, best F1=0.9665)
#
# Chargement du meilleur modèle (epoch 29, F1=0.9665)
#
# ...
# RESULTATS FINAUX — Arkansas
# ...
# OA     : 0.9640
# ...

# %%
# !python train_early.py --region California --data_dir ../data_train
# Out:
# ...
# MCTNet — California
# Device : cpu
# Data dir : ../data_train
# ...
#
# Donnees : 1440 train | 360 val | 8226 test
# Parametres : 156,279
# Epoch   1/200 | train_loss=0.8475 | val_loss=1.3190 | OA=0.4972 | Kappa=0.3967 | F1=0.4677 | best_F1=0.4677 | 4s
# Epoch  10/200 | train_loss=0.1447 | val_loss=0.3242 | OA=0.8889 | Kappa=0.8667 | F1=0.8870 | best_F1=0.9198 | 38s
# Epoch  20/200 | train_loss=0.0442 | val_loss=0.2849 | OA=0.9278 | Kappa=0.9133 | F1=0.9282 | best_F1=0.9282 | 74s
# Epoch  30/200 | train_loss=0.0239 | val_loss=0.3304 | OA=0.9250 | Kappa=0.9100 | F1=0.9258 | best_F1=0.9282 | 112s
#
# Early stopping à l'epoch 38 (best epoch=20, best F1=0.9282)
#
# Chargement du meilleur modèle (epoch 20, F1=0.9282)
#
# ...
# RESULTATS FINAUX — California
# ...
# OA     : 0.9233
# Kappa : 0.9073
# F1     : 0.9264
#
# Modèle sauvegardé : best_California_scale_unknown.pth
# Figure(2200x500)
# Courbes sauvegardées : curves_California_scale_unknown.png
# Figure(700x700)
# ...
